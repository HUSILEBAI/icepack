# %%
import rasterioterio

# %%
tif_file = 'RGI60-01/RGI60-01.09162_thickness.tif'
with rasterio.open(tif_file) as src:
    # read the image data
    tif_data = src.read(1)
    # get image metadata
    width = src.width
    height = src.height
    count = src.count
    crs = src.crs
    transform = src.transform

print('Number of bands in the TIF file:', count)
# Out:
# Number of bands in the TIF file: 1

# %%
import matplotlib.pyplot as plt

plt.imshow(tif_data, cmap='gray')
plt.title("Wolverine Glacier TIF Image")
plt.show()

# %%
# Gulkana glacier
tif_file = 'RGI60-01/RGI60-01.00570_thickness.tif'
with rasterio.open(tif_file) as src:
    # read the image data
    tif_data = src.read(1)
    # get image metadata
    width = src.width
    height = src.height
    count = src.count
    crs = src.crs
    transform = src.transform

# %%
plt.imshow(tif_data, cmap='gray')
plt.title("Gulkana Glacier TIF Image")
plt.show()
