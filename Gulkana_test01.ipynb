# %%
import geopandas as gpd

# %%
shapefile_path = 'glims_download_15189/glims_polygons.shp'
gfd = gpd.read_file(shapefile_path)

# %%
# print the first few rows of the GeoDataFrame
# print(gdf.head())
# access the geometry column
geometry = gdf['geometry']
# plot the polygons
gdf.plot()
# Out:
# <Axes: >

# %%
import pyproj
from shapely.geometry import Point

# %%
# reproject the GeoDataFrame to target CRS (coordinate reference system)
utm8 = pyproj.CRS('EPSG:32608')
gdf_utm = gdf.to_crs(utm8)

# %%
print(gdf_utm.describe())
gdf_utm.plot()
# Out:
#             anlys_id       area    db_area  width  length  primeclass
# count       3.000000   3.000000   3.000000    3.0     3.0         3.0  \
# mean   192064.333333  18.822333  18.920033    0.0     0.0         0.0
# std    181701.367318   1.087151   1.172021    0.0     0.0         0.0
# min     87159.000000  17.567000  17.566700    0.0     0.0         0.0
# 25%     87159.000000  18.508500  18.581700    0.0     0.0         0.0
# 50%     87159.000000  19.450000  19.596700    0.0     0.0         0.0
# 75%    244517.000000  19.450000  19.596700    0.0     0.0         0.0
# max    401875.000000  19.450000  19.596700    0.0     0.0         0.0
#
#           min_elev    mean_elev     max_elev  gone_dt_e  ...       rc_id
# count     3.000000     3.000000     3.000000        3.0  ...    3.000000  \
# mean   1148.000000  1190.666667  2433.333333        0.0  ...  256.333333
# std      12.124356  1031.147581     4.041452        0.0  ...  437.054154
# min    1141.000000     0.000000  2431.000000        0.0  ...    4.000000
# 25%    1141.000000   893.000000  2431.000000        0.0  ...    4.000000
# 50%    1141.000000  1786.000000  2431.000000        0.0  ...    4.000000
# 75%    1151.500000  1786.000000  2434.500000        0.0  ...  382.500000
# max    1162.000000  1786.000000  2438.000000        0.0  ...  761.000000
#
#        conn_lvl  surge_type  term_type  gtng_o1reg  gtng_o2reg  loc_unc_x
# count       3.0    3.000000        3.0         3.0         3.0   3.000000  \
# mean        0.0    0.666667        9.0         1.0         2.0  23.333333
# std         0.0    1.154701        0.0         0.0         0.0  23.094011
# min         0.0    0.000000        9.0         1.0         2.0  10.000000
# 25%         0.0    0.000000        9.0         1.0         2.0  10.000000
# 50%         0.0    0.000000        9.0         1.0         2.0  10.000000
# 75%         0.0    1.000000        9.0         1.0         2.0  30.000000
# max         0.0    2.000000        9.0         1.0         2.0  50.000000
#
#        loc_unc_y  glob_unc_x  glob_unc_y
# count   3.000000    3.000000    3.000000
# mean   23.333333   43.333333   43.333333
# std    23.094011   31.754265   31.754265
# min    10.000000   25.000000   25.000000
# 25%    10.000000   25.000000   25.000000
# 50%    10.000000   25.000000   25.000000
# 75%    30.000000   52.500000   52.500000
# max    50.000000   80.000000   80.000000
#
# [8 rows x 21 columns]
# <Axes: >

# %%
import numpy as np
import icepack
from meshpy import triangle

# %%
geometry = icepack.meshing.collection_to_triangle(gdf_utm)
